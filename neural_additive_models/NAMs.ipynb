# %%
# !set SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True
# !$env:SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL = "True"
# !pip3 install -U --verbose -e "git+https://github.com/agarwl/google-research.git#egg=neural_additive_models&subdirectory=neural_additive_models" # install a python package from a repo subdirectory
# Out:
# zsh:1: command not found: :SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL
# Using pip 25.0 from /opt/anaconda3/envs/notebook/lib/python3.12/site-packages/pip (python 3.12)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Obtaining neural_additive_models from git+https://github.com/agarwl/google-research.git#egg=neural_additive_models&subdirectory=neural_additive_models
#   Running command git config --get-regexp 'remote\..*\.url'
#   remote.origin.url https://github.com/agarwl/google-research.git
#   Updating ./src/neural-additive-models clone
#   Running command git version
#   git version 2.39.5 (Apple Git-154)
#   Running command git fetch -q --tags
#   Running command git show-ref HEAD
#   f9c972a650377695469baf1fde0e49b6f6e8da7c refs/remotes/origin/HEAD
#   Running command git reset --hard -q f9c972a650377695469baf1fde0e49b6f6e8da7c
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
# ...

# %%
# !pip3 install -U --verbose -e "git+https://github.com/agarwl/google-research.git#egg=neural_additive_models&subdirectory=neural_additive_models" --no-deps
# Out:
# Using pip 25.0 from /opt/anaconda3/envs/notebook/lib/python3.12/site-packages/pip (python 3.12)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Obtaining neural_additive_models from git+https://github.com/agarwl/google-research.git#egg=neural_additive_models&subdirectory=neural_additive_models
#   Running command git config --get-regexp 'remote\..*\.url'
#   remote.origin.url https://github.com/agarwl/google-research.git
#   Updating ./src/neural-additive-models clone
#   Running command git version
#   git version 2.39.5 (Apple Git-154)
#   Running command git fetch -q --tags
#   Running command git show-ref HEAD
#   f9c972a650377695469baf1fde0e49b6f6e8da7c refs/remotes/origin/HEAD
#   Running command git reset --hard -q f9c972a650377695469baf1fde0e49b6f6e8da7c
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
# ...
